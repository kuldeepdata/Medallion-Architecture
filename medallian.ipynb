# %%
# %sql
create database if not exists bronze;
create database if not exists silver;
create database if not exists gold;

# %%
# %sql
select * from bronze.orders limit 10;

# %%
df_bronze = spark.table("bronze.orders")
df_silver = spark.table("bronze.orders")

# %%
df_silver.write.mode("append").saveAsTable("silver.orders")

# %%
display.df_silver

# %%
# %sql
select product, quantity, country from silver.orders

# %%
df_gold = df_silver.select("product", "quantity", "country")
display(df_gold)

# %%
# %sql
select * from bronze.orders limit 5;

# %%
# %sql
select * from silver.orders limit 5;

# %%
# %sql
select
product,
quantity,
country
from
gold.product_quantity
limit
5

# %%
df_unpivoted = df_gold.selectExpr(
    "country",
    "stack(5, 'india', india, 'canada', canada, 'australia', australia, 'japan', japan, 'uk', uk) as (country_name, quantity)"
)
display(df_gold)
